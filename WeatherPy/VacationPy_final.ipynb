# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path

# Import API key
from config import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = Path("cities.csv")
city_data_df = pd.read_csv(csv_file)

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0        0        hargeysa   9.5600  44.0650     26.21        44          80
# 1        1  puerto natales -51.7236 -72.4875     -5.09        94         100
# 2        2           prado -17.3411 -39.2208     19.66        96          74
# 3        3      nova odesa  47.3078  31.7851     28.95        45          48
# 4        4            axum  14.1245  38.7244     20.12        59          98
#
#    Wind Speed Country        Date
# 0       13.70      SO  1690269561
# 1        0.63      CL  1690269561
# 2        2.31      BR  1690269307
# 3        7.68      UA  1690269562
# 4        0.89      ET  1690269563

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_plot=city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    frame_width = 800,
    frame_height = 600,
    tiles="OSM",
    size="Humidity",
    scale=0.75,
    color="City"
)

# Display the map
city_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_city_weather=city_data_df[(city_data_df['Max Temp']>=20) & (city_data_df['Max Temp']<=28)&(city_data_df['Cloudiness']==0)&(city_data_df['Wind Speed']<4)]
ideal_city_weather

# Drop any rows with null values
cleaned_city_weather=ideal_city_weather.dropna()

# Display sample data
cleaned_city_weather
# Out:
#      City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 22        22        bethel  41.3712  -73.4140     23.63        84           0
# 53        53       saurimo  -9.6608   20.3916     22.54        31           0
# 57        57     belyy yar  53.6039   91.3903     25.94        50           0
# 160      160     karacabey  40.2152   28.4038     26.21        34           0
# 214      214    greenville  35.6127  -77.3663     23.09        94           0
# 222      222        palmas -10.2128  -48.3603     22.93        53           0
# 227      227        nobres -14.7203  -56.3275     20.03        46           0
# 230      230      hamilton  39.1834  -84.5333     20.23        94           0
# 233      233         sinop  41.7711   34.8709     22.24        46           0
# 272      272     ouarzazat  30.9189   -6.8934     27.16        26           0
# 273      273    rockingham  42.9668  -71.0995     20.95        86           0
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df=cleaned_city_weather[['City','Country','Lat','Lng','Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df.insert(5,"Hotel Name", " ")

# Display sample data
hotel_df1=hotel_df.reset_index(drop=True)
hotel_df1
# Out:
#             City Country      Lat       Lng  Humidity Hotel Name
# 0         bethel      US  41.3712  -73.4140        84
# 1        saurimo      AO  -9.6608   20.3916        31
# 2      belyy yar      RU  53.6039   91.3903        50
# 3      karacabey      TR  40.2152   28.4038        34
# 4     greenville      US  35.6127  -77.3663        94
# 5         palmas      BR -10.2128  -48.3603        53
# 6         nobres      BR -14.7203  -56.3275        46
# 7       hamilton      US  39.1834  -84.5333        94
# 8          sinop      TR  41.7711   34.8709        46
# 9      ouarzazat      MA  30.9189   -6.8934        26
# 10    rockingham      US  42.9668  -71.0995        86
# 11     poinciana      US  28.1403  -81.4584        89
# 12   vilyuchinsk      RU  52.9306  158.4028        67
# 13        urucui      BR  -7.2294  -44.5561        48
# 14      altamira      BR  -3.2033  -52.2064        68
# 15       thomson      US  33.4707  -82.5046        94
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000


params = {
    'categories':"accommodation.hotel",
    'apiKey':geoapify_key,
    'limit':20
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df1.iterrows():
    latitude=hotel_df1.loc[index,'Lat']
    longitude=hotel_df1.loc[index, 'Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
   # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df1.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df1.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df1.loc[index, 'City']} - nearest hotel: {hotel_df1.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df1
# Out:
# Starting hotel search
# bethel - nearest hotel: Hampton Inn Danbury
# saurimo - nearest hotel: Complexo Hoteleiro de Saurimo
# belyy yar - nearest hotel: No hotel found
# karacabey - nearest hotel: Ün Otel
# greenville - nearest hotel: Quality Inn
# palmas - nearest hotel: Hotel Triângulo Mineiro
# nobres - nearest hotel: No hotel found
# hamilton - nearest hotel: North Vista Manor
# sinop - nearest hotel: No hotel found
# ouarzazat - nearest hotel: Fint
# rockingham - nearest hotel: No hotel found
# poinciana - nearest hotel: No hotel found
# vilyuchinsk - nearest hotel: Победа
# urucui - nearest hotel: Formula Flat hotel
# altamira - nearest hotel: Hotel Vale do Xingu
# thomson - nearest hotel: Days Inn by Wyndham Thomson
# griffith - nearest hotel: Quality Inn & Suites
# tirhanimine - nearest hotel: Mira Palace
# fort bragg - nearest hotel: Airborne Inn Lodging
# huntersville - nearest hotel: BEST WESTERN Plus Huntersville Inn & Suites Near Lake Norman
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map = hotel_df1.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    scale = 1.5,
    size='Humidity',
    color = "City",
    hover_cols = ["Country", "Hotel Name"]
)

# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country,Hotel Name)
